# %% [markdown]
# <a href="https://colab.research.google.com/github/yadaginimahivardhan/FMML_PROJECT/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 08:10:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   143MB/s    in 0.5s
#
# 2025-03-13 08:10:04 (143 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 8772   cs/0408037v1  We investigate the possibility of modelling th...    cs
# 28463  1706.07530v1  The emergence of depth imaging technologies li...    cs
# 12323  1711.08426v1  Given a matrix $\mathbf{A}\in\mathbb{R}^{n\tim...  stat
# 32092   1207.3790v1  The selection of the best classification algor...    cs
# 13098  1512.02896v1  Most users of online services have unique beha...    cs
# ...             ...                                                ...   ...
# 4419   1707.02432v2  Semantic segmentation was seen as a challengin...  stat
# 1849   1710.04099v1  I present a web service for querying an embedd...  stat
# 6028   1606.02838v2  Learning parameters from voluminous data can b...    cs
# 25365  1508.00998v2  In this paper we present a method for the esti...    cs
# 805    1607.08878v1  As data science continues to grow in popularit...    cs
#
#                                                    title  year  \
# 8772   Multi-dimensional Type Theory: Rules, Categori...  2004
# 28463  Multiresolution Match Kernels for Gesture Vide...  2017
# 12323  Leverage Score Sampling for Faster Accelerated...  2017
# 32092  Accuracy Measures for the Comparison of Classi...  2012
# 13098  Where You Are Is Who You Are: User Identificat...  2015
# ...                                                  ...   ...
# 4419   Deep Semantic Segmentation for Automated Drivi...  2017
# 1849    Wembedder: Wikidata entity embedding web service  2017
# 6028   Sketching for Large-Scale Learning of Mixture ...  2016
# 25365  Single and Multiple Illuminant Estimation Usin...  2015
# 805    Identifying and Harnessing the Building Blocks...  2016
#
#                                                 keywords
# 8772   [investigate, possibility, modelling, semantic...
# 28463  [emergence, technologies, microsoft, computati...
# 12323  [mathbfainmathbbrntimes, inmathbbrd, approxima...
# 32092  [selection, classification, algorithm, widespr...
# 13098  [behavioral, behavioral, exploited, identifyin...
# ...                                                  ...
# 4419   [segmentation, challenging, advancements, rela...
# 1849   [embedding, knowledge, embedding, implementati...
# 6028   [parameters, voluminous, prohibitive, computat...
# 25365  [estimation, illuminant, convolutional, specia...
# 805    [continues, popularity, increasing, accessible...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 8772     [investigate, possibility, modelling, semantic...
# 28463    [emergence, technologies, microsoft, computati...
# 12323    [mathbfainmathbbrntimes, inmathbbrd, approxima...
# 32092    [selection, classification, algorithm, widespr...
# 13098    [behavioral, behavioral, exploited, identifyin...
#                                ...
# 11426    [experiments, quantities, interpreted, physici...
# 7588     [wasserstein, increasingly, important, stochas...
# 24157    [probabilistic, autoregressive, architectures,...
# 22701    [emergence, development, accumulated, processe...
# 25787    [dictionaries, component, classificationretrie...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4540 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9823e97-3f30-476d-aab3-7b1bc34e086e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9823e97-3f30-476d-aab3-7b1bc34e086e")) {                    Plotly.newPlot(                        "e9823e97-3f30-476d-aab3-7b1bc34e086e",                        [{"x":["traditional","categories","modelling","semantics","complicated","explicitly","combinators","additional","dimensional","dimension","operations","dimensions","possibility","categorial","implementations","important","pragmatics","addressed","investigate","multiplicity","constraints","perspective","interpretation","repertoire","procedure","intrinsic","microsoft","different","multiresolution","similarity","usefulness","information","researchers","recognition","considered","extracted","generation","emergence","generalization","representation","computational","technologies","histogram","locations","classification","polylogarithmic","accelerated","approximate","coordinate","algorithm","techniques","performance","combination","regression","algorithms","preferred","properties","consequently","comparison","widespread","unsuitable","selection","classifiers","equivalent","methodological","simultaneous","identified","introduced","behavioral","identification","effectiveness","approaches","histories","identifying","fingerprints","exploited","statistics","scenarios","experiments","specifically","practical","heuristics","identities","collection","affecting","resolution","histograms","trajectories","collected","anonymized","attributed","particular","processing","laplacian","transform","conventional","clustering","maximizing","introduce","localized","organization","classical","establish","eigendecomposition","predefined","concentration","frequencies","interactions","embedding","eigenvalue","parameters","factorize","distributions","theoretic","faithfulness","described","selecting","particularly","attentive","framework","cluttered","attention","performed","containing","auxiliary","discriminative","difficult","subsequent","background","pedestrian","convergence","irrelevant","recurrent","differentiable","evaluation","hierarchical","environments","producing","logarithmic","theoretically","faithfully","guaranteed","representations","reconstruct","distances","unfolding","reduction","euclidean","asymptotic","optimization","represented","estimator","programming","nonlinear","computation","partially","multidimensional","numerical","dimensionality","configuration","numerically","configurations","drawbacks","variational","contaminated","potentially","consuming","uncertainty","applications","component","overfitting","parameter","classifier","independent","efficient","constrained","quadratic","characterized","objective","estimation","outperform","susceptible","especially","likelihood","consistency","demonstrate","neighbourhood","mechanism","posterior","challenging","available","observations","availability","requiring","projection","effectively","developed","appearances","constructs","variations"],"y":[176,79,53,86,33,70,2,113,196,73,91,46,31,6,37,344,3,34,163,3,152,62,59,1,128,46,8,723,3,134,34,709,100,389,128,111,154,16,110,335,280,37,27,40,520,2,21,106,22,784,395,874,129,128,584,16,205,29,125,13,3,178,115,57,8,32,42,124,18,95,210,406,4,72,6,36,54,90,558,166,127,39,8,87,10,118,9,18,79,2,10,287,296,17,60,105,155,29,328,15,20,104,48,2,16,14,25,69,85,4,248,0,116,42,0,64,55,82,9,561,7,154,122,68,25,92,148,27,68,21,105,24,137,28,260,101,75,20,17,40,5,34,232,30,19,2,99,34,21,309,90,25,114,52,134,54,8,69,64,33,7,25,17,60,6,44,35,99,411,103,22,113,161,148,405,49,35,30,181,199,118,4,116,64,60,575,4,99,38,263,293,72,32,47,52,115,209,7,16,69],"type":"bar"},{"x":["traditional","categories","modelling","semantic ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4540,), (4540, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7925

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Version</span> <span style=''>of</span> <span style=''>Geiringer</span> <span style=''>like</span> <span style=''>Theorem</span> <span style=''>for</span> <span style=''>Decision</span> <span style=''>Making</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363636);'>Environments</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Randomness</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Incomplete</span> <span style='background-color:rgba(0, 255, 0, 0.3178438661710037);'>Information</span> <br/><br/><span style=''>Purpose</span> <span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>sampling</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>tree</span> <span style=''>search</span> <span style=''>have</span> <span style=''>achieved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tremendous</span> <span style=''>success</span> <span style=''>in</span> <span style=''>model</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.5286624203821655);'>reinforcement</span> <span style=''>learning</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style=''>upper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>bounds</span> <span style=''>policy</span> <span style=''>to</span> <span style=''>preserve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploration</span> <span style=''>vs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploitation</span> <span style=''>balance</span> <span style=''>to</span> <span style=''>select</span> <span style=''>actions</span> <span style=''>for</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluations</span> <span style=''>together</span> <span style=''>with</span> <span style=''>massive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>power</span> <span style=''>to</span> <span style=''>store</span> <span style=''>and</span> <span style=''>to</span> <span style=''>update</span> <span style='background-color:rgba(0, 255, 0, 0.40425531914893625);'>dynamically</span> <span style=''>a</span> <span style=''>rather</span> <span style=''>large</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.4271844660194175);'>evaluated</span> <span style=''>game</span> <span style=''>tree</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4835164835164834);'>development</span> <span style=''>of</span> <span style=''>software</span> <span style=''>that</span> <span style=''>has</span> <span style=''>beaten</span> <span style=''>the</span> <span style=''>top</span> <span style=''>human</span> <span style=''>player</span> <span style=''>in</span> <span style=''>the</span> <span style=''>game</span> <span style=''>of</span> <span style=''>Go</span> <span style=''>on</span> <span style=''>a</span> <span style=''>9</span> <span style=''>by</span> <span style=''>9</span> <span style=''>board</span> <span style=''>Much</span> <span style=''>effort</span> <span style=''>in</span> <span style=''>the</span> <span style=''>current</span> <span style=''>research</span> <span style=''>is</span> <span style=''>devoted</span> <span style=''>to</span> <span style=''>widening</span> <span style=''>the</span> <span style=''>range</span> <span style=''>of</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Deterministic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Conditions</span> <span style=''>for</span> <span style=''>Subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifiability</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Incomplete</span> <span style=''>Sampling</span> <br/><br/><span style=''>Consider</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>r</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>subspace</span> <span style=''>of</span> <span style=''>mathbbRd</span> <span style=''>rd</span> <span style=''>and</span> <span style=''>suppose</span> <span style=''>that</span> <span style=''>we</span> <span style=''>are</span> <span style=''>only</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>this</span> <span style=''>subspace</span> <span style=''>onto</span> <span style=''>small</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>canonical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinates</span> <span style=''>The</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establishes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>the</span> <span style=''>subsets</span> <span style=''>for</span> <span style=''>subspace</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifiability</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fixed</span> <span style=''>Rank</span> <span style='background-color:rgba(0, 255, 0, 0.36734693877551017);'>Representation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style=''>Visual</span> <span style=''>Learning</span> <br/><br/><span style=''>Subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.536723163841808);'>extraction</span> <span style=''>are</span> <span style=''>two</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>commonly</span> <span style=''>used</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>pattern</span> <span style='background-color:rgba(0, 255, 0, 0.6276150627615062);'>recognition</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style=''>subspace</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>make</span> <span style=''>use</span> <span style=''>of</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>However</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style=''>may</span> <span style=''>result</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>degenerate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>that</span> <span style=''>degrade</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>insufficient</span> <span style=''>data</span> <span style=''>sampling</span> <span style=''>To</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>solve</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>existing</span> <span style=''>work</span> <span style=''>on</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4915254237288136);'>factorization</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>fixed</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.36734693877551017);'>representation</span> <span style=''>(FRR)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>visual</span> <span style=''>learning</span> <span style=''>FRR</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>reveal</span> <span style=''>the</span> <span style='background-color:rgba(0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MARGIN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Uncovering</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>using</span> <span style=''>Graph</span> <span style=''>Signal</span> <span style=''>Analysis</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Interpretability</span> <span style=''>has</span> <span style=''>emerged</span> <span style=''>as</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>aspect</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>aimed</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>insights</span> <span style=''>into</span> <span style=''>the</span> <span style=''>working</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>However</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>vary</span> <span style=''>vastly</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>task</span> <span style=''>with</span> <span style=''>each</span> <span style=''>use</span> <span style=''>case</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style=''>time</span> <span style=''>and</span> <span style=''>effort</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>MARGIN</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style=''>general</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>address</span> <span style=''>a</span> <span style=''>large</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>tasks</span> <span style=''>ranging</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prototypes</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explaining</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>MARGIN</span> <span style=''>exploits</span> <span style=''>ideas</span> <span style=''>rooted</span> <span style=''>in</span> <span style=''>graph</span> <span style=''>signal</span> <span style=''>analysis</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influential</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>which</span> <span style=''>are</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>those</span> <span style=''>nodes</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximally</span> <span style=''>describe</span> <span style=''>a</span> <span style=''>function</span> <span style=''>defined</span> <span style=''>on</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>defining</span> <span style=''>task</span> <span style=''>specific</span> <span style=''>graphs</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09286723163841808)
# 	evaluation (0.09180790960451977)
# 	processing (0.10451977401129943)
# 	segmentation (0.06567796610169492)
# 	experimental (0.13453389830508475)
# 	information (0.2503531073446328)
# 	different (0.2552966101694915)
# 	detection (0.14124293785310735)
# 	convolutional (0.129590395480226)
# 	recognition (0.1373587570621469)
#
# Some Statistics words are:
# 	stochastic (0.13567073170731708)
# 	theoretical (0.1524390243902439)
# 	variables (0.1407520325203252)
# 	statistical (0.15548780487804878)
# 	estimation (0.18191056910569106)
# 	inference (0.19054878048780488)
# 	distribution (0.1875)
# 	dimensional (0.19461382113821138)
# 	algorithm (0.4065040650406504)
# 	regression (0.17682926829268292)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21a1b779-4706-4c2e-8c69-fb36c9f831e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21a1b779-4706-4c2e-8c69-fb36c9f831e3")) {                    Plotly.newPlot(                        "21a1b779-4706-4c2e-8c69-fb36c9f831e3",                        [{"x":["traditional","categories","modelling","semantics","complicated","explicitly","combinators","additional","dimensional","dimension","operations","dimensions","possibility","categorial","implementations","important","pragmatics","addressed","investigate","multiplicity","constraints","perspective","interpretation","repertoire","procedure","intrinsic","microsoft","different","multiresolution","similarity","usefulness","information","researchers","recognition","considered","extracted","generation","emergence","generalization","representation","computational","technologies","histogram","locations","classification","polylogarithmic","accelerated","approximate","coordinate","algorithm","techniques","performance","combination","regression","algorithms","preferred","properties","consequently","comparison","widespread","unsuitable","selection","classifiers","equivalent","methodological","simultaneous","identified","introduced","behavioral","identification","effectiveness","approaches","histories","identifying","fingerprints","exploited","statistics","scenarios","experiments","specifically","practical","heuristics","identities","collection","affecting","resolution","histograms","trajectories","collected","anonymized","attributed","particular","processing","laplacian","transform","conventional","clustering","maximizing","introduce","localized","organization","classical","establish","eigendecomposition","predefined","concentration","frequencies","interactions","embedding","eigenvalue","parameters","factorize","distributions","theoretic","faithfulness","described","selecting","particularly","attentive","framework","cluttered","attention","performed","containing","auxiliary","discriminative","difficult","subsequent","background","pedestrian","convergence","irrelevant","recurrent","differentiable","evaluation","hierarchical","environments","producing","logarithmic","theoretically","faithfully","guaranteed","representations","reconstruct","distances","unfolding","reduction","euclidean","asymptotic","optimization","represented","estimator","programming","nonlinear","computation","partially","multidimensional","numerical","dimensionality","configuration","numerically","configurations","drawbacks","variational","contaminated","potentially","consuming","uncertainty","applications","component","overfitting","parameter","classifier","independent","efficient","constrained","quadratic","characterized","objective","estimation","outperform","susceptible","especially","likelihood","consistency","demonstrate","neighbourhood","mechanism","posterior","challenging","available","observations","availability","requiring","projection","effectively","developed","appearances","constructs","variations","appearance","enhancing","supervised","experimental","unlabeled","iteratively","bottleneck","linearity","relationships","comparable","promising","neighbors","incorporated","insufficient","characters","piecewise","character","hypothesis","relationship","distribution","previously","characterizing","empirically","functions","distinguishing","criterion","prediction","corresponds","aggregate","corresponding","estimates","regularizer","connections","understanding","equivalence","naturally","regularized","interpreted","mathematical","restriction","simulations","soundness","multiplication","transition","construction","relations","derivative","completeness","simulator","operating","inherently","expressive","simulation ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	factorize
# 	faithfulness
# 	metabolites
# 	unnormalized
# 	affinities
# 	inversions
# 	coherently
# 	frequentist
# 	katehakis
# 	infectious
# 	checkable
# 	incidentally
# 	framelets
# 	recombines
# 	marginalizing
# 	distributionally
# 	inspecting
# 	parsimonious
# 	robustification
# 	multitype
# Some words which never appear in Statistics papers:
# 	combinators
# 	categorial
# 	pragmatics
# 	multiplicity
# 	identities
# 	attentive
# 	soundness
# 	constancy
# 	vibration
# 	cylindrical
# 	cylinders
# 	readability
# 	registrations
# 	declarative
# 	predicates
# 	neocortex
# 	practicability
# 	subsystems
# 	recognizers
# 	acoustics

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.043213633597079e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.745
